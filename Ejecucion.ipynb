# %%
# Ejecución del programa principal

# Importar funciones de otros notebooks
from src.cargar_datos import cargar_datos
#from src.procesamiento_datos import procesar_datos
#from src.analisis_datos import calcular_distancia_promedio
#from src.visualizacion_datos import generar_mapa

# Cargar datos
datos = cargar_datos('data.data_gps.csv')

# Procesar datos
#datos_procesados = procesar_datos(datos)

# Análisis
#calcular_distancia_promedio(datos_procesados)

# Visualización
#generar_mapa(datos_procesados)
# Out:
# Error al cargar los datos: [Errno 2] No such file or directory: 'data.data_gps.csv'
