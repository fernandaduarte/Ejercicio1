# %%
# Ejecución del programa principal

# Importar funciones de otros notebooks
from cargar_datos import cargar_datos
from procesamiento_datos import procesar_datos
from analisis_datos import calcular_distancia_promedio
from visualizacion_datos import generar_mapa

# Cargar datos
datos = cargar_datos(data_gps)

# Procesar datos
datos_procesados = procesar_datos(datos)

# Análisis
calcular_distancia_promedio(datos_procesados)

# Visualización
generar_mapa(datos_procesados)
# Out:
# ERROR: Could not find a version that satisfies the requirement cargar_datos (from versions: none)
# ERROR: No matching distribution found for cargar_datos
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 7
#       4 get_ipython().run_line_magic('pip', 'install cargar_datos procesamiento_datos analisis_datos visualizacion_datos')
#       6 # Importar funciones de otros notebooks
# ----> 7 from cargar_datos import cargar_datos
#       8 from procesamiento_datos import procesar_datos
#       9 from analisis_datos import calcular_distancia_promedio
#
# ModuleNotFoundError: No module named 'cargar_datos'
